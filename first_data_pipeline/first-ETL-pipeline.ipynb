# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# %%
url = "https://api.sampleapis.com/wines/reds"

data = requests.get(url).json()

# Raw data from wines API
data[:5]
# Out:
# [{'winery': 'Maselva',
#   'wine': 'Emporda 2012',
#   'rating': {'average': '4.9', 'reviews': '88 ratings'},
#   'location': 'Spain\n·\nEmpordà',
#   'image': 'https://images.vivino.com/thumbs/ApnIiXjcT5Kc33OHgNb9dA_375x500.jpg',
#   'id': 1},
#  {'winery': 'Ernesto Ruffo',
#   'wine': 'Amarone della Valpolicella Riserva N.V.',
#   'rating': {'average': '4.9', 'reviews': '75 ratings'},
#   'location': 'Italy\n·\nAmarone della Valpolicella',
#   'image': 'https://images.vivino.com/thumbs/nC9V6L2mQQSq0s-wZLcaxw_pb_x300.png',
#   'id': 2},
#  {'winery': 'Cartuxa',
#   'wine': 'Pêra-Manca Tinto 1990',
#   'rating': {'average': '4.9', 'reviews': '72 ratings'},
#   'location': 'Portugal\n·\nAlentejo',
#   'image': 'https://images.vivino.com/thumbs/L33jsYUuTMWTMy3KoqQyXg_pb_x300.png',
#   'id': 3},
#  {'winery': 'Schrader',
#   'wine': 'Cabernet Sauvignon RBS Beckstoffer To Kalon Vineyard 2015',
#   'rating': {'average': '4.9', 'reviews': '72 ratings'},
#   'location': 'United States\n·\nOakville',
#   'image': 'https://images.vivino.com/thumbs/GpcSXs2ERS6niDxoAsvESA_pb_x300.png',
#   'id': 4},
#  {'winery': 'Hundred Acre',
#   'wine': 'Wraith Cabernet Sauvignon 2013',
#   'rating': {'average': '4.9', 'reviews': '68 ratings'},
#   'location': 'United States\n·\nNapa Valley',
#   'image': 'https://images.vivino.com/thumbs/PBhGMcRNQ7aVnVNr7VgnWA_pb_x300.png',
#   'id': 5}]

# %%
df = pd.DataFrame(data)

# Dataframe before transformation
df
# Out:
#                    winery                                               wine  \
# 0                 Maselva                                       Emporda 2012
# 1           Ernesto Ruffo            Amarone della Valpolicella Riserva N.V.
# 2                 Cartuxa                              Pêra-Manca Tinto 1990
# 3                Schrader  Cabernet Sauvignon RBS Beckstoffer To Kalon Vi...
# 4            Hundred Acre                     Wraith Cabernet Sauvignon 2013
# ..                    ...                                                ...
# 713               Dominus                    Dominus (Christian Moueix) 2013
# 714  Château Cheval Blanc  Saint-Émilion Grand Cru (Premier Grand Cru Cla...
# 715               Masseto                                       Toscana 2011
# 716               Soldera                Brunello di Montalcino Riserva 2005
# 717            Pine Ridge                     Fortis Cabernet Sauvignon N.V.
#
#                                            rating  \
# 0     {'average': '4.9', 'reviews': '88 ratings'}
# 1     {'average': '4.9', 'reviews': '75 ratings'}
# 2     {'average': '4.9', 'reviews': '72 ratings'}
# 3     {'average': '4.9', 'reviews': '72 ratings'}
# 4     {'average': '4.9', 'reviews': '68 ratings'}
# ..                                            ...
# 713  {'average': '4.7', 'reviews': '548 ratings'}
# 714  {'average': '4.7', 'reviews': '546 ratings'}
# 715  {'average': '4.7', 'reviews': '546 ratings'}
# 716  {'average': '4.7', 'reviews': '546 ratings'}
# 717  {'average': '4.7', 'reviews': '546 ratings'}
#
#                                  location  \
# 0                       Spain\n·\nEmpordà
# 1    Italy\n·\nAmarone della Valpolicella
# 2                   Portugal\n·\nAlentejo
# 3              United States\n·\nOakville
# 4           United States\n·\nNapa Valley
# ..                                    ...
# 713         United States\n·\nNapa Valley
# 714    France\n·\nSaint-Émilion Grand Cru
# 715                     Italy\n·\nToscana
# 716      Italy\n·\nBrunello di Montalcino
# 717         United States\n·\nNapa Valley
#
#                                                  image   id
# 0    https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...    1
# 1    https://images.vivino.com/thumbs/nC9V6L2mQQSq0...    2
# 2    https://images.vivino.com/thumbs/L33jsYUuTMWTM...    3
# 3    https://images.vivino.com/thumbs/GpcSXs2ERS6ni...    4
# 4    https://images.vivino.com/thumbs/PBhGMcRNQ7aVn...    5
# ..                                                 ...  ...
# 713  https://images.vivino.com/thumbs/FvLdztxrRXOZx...  714
# 714  https://images.vivino.com/thumbs/AIWJqsLoSIyz0...  715
# 715  https://images.vivino.com/thumbs/GPvEr_IUSKS1C...  716
# 716  https://images.vivino.com/thumbs/l_eXmV1KTdGzz...  717
# 717  https://images.vivino.com/thumbs/nu85uiOyQiay0...  718
#
# [718 rows x 6 columns]

# %%
# Seperating country and city from location column
df['country'] = df['location'].apply(lambda x: x.split("\n·\n")[0].strip())
df['city'] = df['location'].apply(lambda x: x.split("\n·\n")[1].strip() if "\n·\n" in x else None)

# seperating avg_rating and reviews from rating cloumn
ratings =[]
reviews =[]
for rating in data:
    ratings.append(float(rating["rating"]["average"]))
    reviews.append(int(rating["rating"]["reviews"].split()[0]))

df["avg_rating"] = ratings
df["total_reviews"] = reviews

# Deleting unnecessary columns
df.drop(columns =["location","rating"], inplace=True)

# %%
# Dataframe after transformation
df
# Out:
#                    winery                                               wine  \
# 0                 Maselva                                       Emporda 2012
# 1           Ernesto Ruffo            Amarone della Valpolicella Riserva N.V.
# 2                 Cartuxa                              Pêra-Manca Tinto 1990
# 3                Schrader  Cabernet Sauvignon RBS Beckstoffer To Kalon Vi...
# 4            Hundred Acre                     Wraith Cabernet Sauvignon 2013
# ..                    ...                                                ...
# 713               Dominus                    Dominus (Christian Moueix) 2013
# 714  Château Cheval Blanc  Saint-Émilion Grand Cru (Premier Grand Cru Cla...
# 715               Masseto                                       Toscana 2011
# 716               Soldera                Brunello di Montalcino Riserva 2005
# 717            Pine Ridge                     Fortis Cabernet Sauvignon N.V.
#
#                                                  image   id        country  \
# 0    https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...    1          Spain
# 1    https://images.vivino.com/thumbs/nC9V6L2mQQSq0...    2          Italy
# 2    https://images.vivino.com/thumbs/L33jsYUuTMWTM...    3       Portugal
# 3    https://images.vivino.com/thumbs/GpcSXs2ERS6ni...    4  United States
# 4    https://images.vivino.com/thumbs/PBhGMcRNQ7aVn...    5  United States
# ..                                                 ...  ...            ...
# 713  https://images.vivino.com/thumbs/FvLdztxrRXOZx...  714  United States
# 714  https://images.vivino.com/thumbs/AIWJqsLoSIyz0...  715         France
# 715  https://images.vivino.com/thumbs/GPvEr_IUSKS1C...  716          Italy
# 716  https://images.vivino.com/thumbs/l_eXmV1KTdGzz...  717          Italy
# 717  https://images.vivino.com/thumbs/nu85uiOyQiay0...  718  United States
#
#                            city  avg_rating  total_reviews
# 0                       Empordà         4.9             88
# 1    Amarone della Valpolicella         4.9             75
# 2                      Alentejo         4.9             72
# 3                      Oakville         4.9             72
# 4                   Napa Valley         4.9             68
# ..                          ...         ...            ...
# 713                 Napa Valley         4.7            548
# 714     Saint-Émilion Grand Cru         4.7            546
# 715                     Toscana         4.7            546
# 716      Brunello di Montalcino         4.7            546
# 717                 Napa Valley         4.7            546
#
# [718 rows x 8 columns]

# %%
# store Dataframe into a SQLlite Database with table name as 'wine_table'
disk_engine = create_engine("sqlite:///my_pipeline_database.db")
df.to_sql('wine_table',disk_engine, if_exists='replace')
# Out:
# 718
